# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenHoang127/AI_Exercise_All/blob/main/Exercise_4_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
url = 'mtcars.csv'
data = pd.read_csv(url)
data.hist()
plt.show()

#correclation là mối tương quan
correclation = data.corr()
print(correclation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
sns.heatmap(correclation,annot=True)
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black')
# Out:
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
#Thư viện Sklearn dùng cho machine learning
from sklearn import linear_model
model = linear_model.LinearRegression() #Hồi quy tuyến tính

model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print(model.intercept_)
print(model.coef_)
# Out:
# 37.28512616734204
# [-5.34447157]

# %%
#Độ chính xác là bao nhiêu %
model.score(X=pd.DataFrame(data['wt']),y=data['mpg'])
# Out:
# 0.7528327936582646

# %%
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
y_prid = model.predict(X=pd.DataFrame(data['wt']))
plt.plot(data['wt'],y_prid,color='blue')

# %%
#Tạo ra mô hình mới
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['mpg']))
# Out:
# Intercept của mô hình 49.93081094945181
# Coeffient của mô hình [-13.38033708   1.17108689]
# Độ chính xác của mô hình 0.8190613581384094

# %%
range = np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Tạo ra mô hình mới bậc 3
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3]).T
model.fit(X,y=data['mpg'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['mpg']))
# Out:
# Intercept của mô hình 48.40369622795221
# Coeffient của mô hình [-11.82597602   0.68937919   0.04593618]
# Độ chính xác của mô hình 0.8191284628478992

# %%
range = np.arange(1.5,6.5,0.1)
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Tạo ra mô hình mới bậc 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình -87.71816314301019
# Coeffient của mô hình [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# Độ chính xác của mô hình 0.8251088272653132
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Tạo ra mô hình mới bậc 10
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model.fit(X,y=data['mpg'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['mpg']))

range = np.arange(1.5,5.5,0.1)
data.plot(kind='scatter',x ='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình -14921.11995188375
# Coeffient của mô hình [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Độ chính xác của mô hình 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Hồi quy 2 biến đầu vào
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp']],y=data['mpg'])
print(model.intercept_)
print(model.coef_)
print(model.score(X=data.loc[:,['wt','hp']],y=data['mpg']))
# Out:
# 37.227270116447215
# [-3.87783074 -0.03177295]
# 0.8267854518827914

# %%
#BT1
url = 'Salary_Data.csv'
data = pd.read_csv(url)
data.hist()
plt.show()

#correclation là mối tương quan
correclation = data.corr()
print(correclation)

sns.pairplot(data)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
data.plot(kind='scatter',x ='YearsExperience',y='Salary',figsize=(9,9),color='black')
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['YearsExperience'],data['YearsExperience']**2,data['YearsExperience']**3,data['YearsExperience']**4,data['YearsExperience']**5]).T
model.fit(X,y=data['Salary'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Salary']))

range = np.arange(0,11.5,0.1)
data.plot(kind='scatter',x ='YearsExperience',y='Salary',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 8315.008085219713
# Coeffient của mô hình [ 4.36519566e+04 -1.93676827e+04  4.40970724e+03 -4.30125541e+02
#   1.50064208e+01]
# Độ chính xác của mô hình 0.9665546834956734
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Tạo ra mô hình mới
model = linear_model.LinearRegression()
X = pd.DataFrame([data['YearsExperience'],data['YearsExperience']**2]).T
model.fit(X,y=data['Salary'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Salary']))

range = np.arange(0,10.5,0.1)
data.plot(kind='scatter',x ='YearsExperience',y='Salary',figsize=(9,9),color='black',xlim=(0,7))
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 26214.932677059565
# Coeffient của mô hình [9259.2838882    16.39256632]
# Độ chính xác của mô hình 0.956975168321065
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#BT1
url = 'Advertising.csv'
data = pd.read_csv(url)
data.hist()
plt.show()

#correclation là mối tương quan
correclation = data.corr()
print(correclation)

#sns.pairplot(data)
sns.heatmap(correclation,annot=True)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000
# <AxesSubplot:>

# %%
data.plot(kind='scatter',x ='TV',y='sales',figsize=(9,9),color='black')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'],data['TV']**2,data['TV']**3,data['TV']**4,data['TV']**5]).T
model.fit(X,y=data['sales'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['sales']))

range = np.arange(data['TV'].min(),data['TV'].max(),10)
data.plot(kind='scatter',x ='TV',y='sales',figsize=(12,12),color='black',xlim=(data['TV'].min(),data['TV'].max()))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 3.434534787401425
# Coeffient của mô hình [ 2.77902843e-01 -4.26334402e-03  3.38693899e-05 -1.20207585e-07
#   1.55728366e-10]
# Độ chính xác của mô hình 0.6289510709142143
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#BT1
url = '50_Startups.csv'
data = pd.read_csv(url)
data.hist()
plt.show()

#correclation là mối tương quan
correclation = data.corr()
print(correclation)

sns.pairplot(data)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
data.plot(kind='scatter',x ='R&D Spend',y='Profit',figsize=(9,9),color='black')
# Out:
# <AxesSubplot:xlabel='R&D Spend', ylabel='Profit'>

# %%
model.fit(X=pd.DataFrame(data['R&D Spend']),y=data['Profit'])
print(model.intercept_)
print(model.coef_)
#Độ chính xác là bao nhiêu %
model.score(X=pd.DataFrame(data['R&D Spend']),y=data['Profit'])
# Out:
# 49032.89914125215
# [0.85429137]
# 0.9465353160804393

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Profit']))

range = np.arange(data['R&D Spend'].min(),data['R&D Spend'].max(),10)
data.plot(kind='scatter',x ='R&D Spend',y='Profit',figsize=(12,12),color='black',xlim=(data['R&D Spend'].min(),data['R&D Spend'].max()))
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 48128.14916956878
# Coeffient của mô hình [ 8.90147291e-01 -2.31821806e-07]
# Độ chính xác của mô hình 0.946703652909133
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y=data['Profit'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Profit']))

range = np.arange(data['R&D Spend'].min(),data['R&D Spend'].max(),10)
data.plot(kind='scatter',x ='R&D Spend',y='Profit',figsize=(12,12),color='black',xlim=(data['R&D Spend'].min(),data['R&D Spend'].max()))
predictor = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 43108.76756818297
# Coeffient của mô hình [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Độ chính xác của mô hình 0.9540709421464032
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4]).T
model.fit(X,y=data['Profit'])
print('Intercept của mô hình',model.intercept_)
print('Coeffient của mô hình',model.coef_)
print('Độ chính xác của mô hình',model.score(X,y=data['Profit']))

range = np.arange(data['R&D Spend'].min(),data['R&D Spend'].max(),10)
data.plot(kind='scatter',x ='R&D Spend',y='Profit',figsize=(12,12),color='black',xlim=(data['R&D Spend'].min(),data['R&D Spend'].max()))
predictor = pd.DataFrame([range,range**2,range**3,range**4]).T
y_pred = model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình 54454.40996740002
# Coeffient của mô hình [ 6.45872939e-10  2.52519103e-05 -2.52720474e-10  8.00998401e-16]
# Độ chính xác của mô hình 0.9338075472558462
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
